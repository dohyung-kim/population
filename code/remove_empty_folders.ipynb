# %%
import subprocess
import pandas as pd
import os
import shutil

# %%
top_foler='/home/dohyungkim/population'
year='2015'

ISO_csv='ISO_codes.csv'
ISOs=pd.read_csv(os.path.join(top_foler, ISO_csv))["ISO3"]

# %%
for ISO in ISOs:
     if not os.path.exists(os.path.join(top_foler,ISO,'population_'+ISO+'.tif')):
            try:
                shutil.rmtree(os.path.join(top_foler,ISO))
                print(ISO + " processing finished!")
            except:
                print(ISO + " processing finished!")
# Out:
# AFG processing finished!
# AND processing finished!
# AIA processing finished!
# ATA processing finished!
# ATG processing finished!
# ARM processing finished!
# AUS processing finished!
# AZE processing finished!
# BLZ processing finished!
# BMU processing finished!
# BES processing finished!
# BVT processing finished!
# BRA processing finished!
# IOT processing finished!
# CAN processing finished!
# CHL processing finished!
# CHN processing finished!
# CXR processing finished!
# CCK processing finished!
# COM processing finished!
# COG processing finished!
# COK processing finished!
# CRI processing finished!
# CUB processing finished!
# CUW processing finished!
# CYP processing finished!
# DNK processing finished!
# DJI processing finished!
# DMA processing finished!
# ERI processing finished!
# FLK processing finished!
# FRO processing finished!
# FJI processing finished!
# FIN processing finished!
# ATF processing finished!
# GEO processing finished!
# GIB processing finished!
# GRL processing finished!
# GGY processing finished!
# HMD processing finished!
# VAT processing finished!
# HUN processing finished!
# IND processing finished!
# IDN processing finished!
# IRN processing finished!
# IRQ processing finished!
# IRL processing finished!
# IMN processing finished!
# ISR processing finished!
# ITA processing finished!
# JAM processing finished!
# JPN processing finished!
# JEY processing finished!
# JOR processing finished!
# KEN processing finished!
# KIR processing finished!
# PRK processing finished!
# KOR processing finished!
# KWT processing finished!
# KGZ processing finished!
# LAO processing finished!
# LVA processing finished!
# LBN processing finished!
# LSO processing finished!
# LBR processing finished!
# LBY processing finished!
# LIE processing finished!
# LTU processing finished!
# LUX processing finished!
# MAC processing finished!
# MDG processing finished!
# MWI processing finished!
# MDV processing finished!
# MLI processing finished!
# MLT processing finished!
# MHL processing finished!
# MTQ processing finished!
# MRT processing finished!
# MUS processing finished!
# MYT processing finished!
# MEX processing finished!
# FSM processing finished!
# MDA processing finished!
# MCO processing finished!
# MNG processing finished!
# MNE processing finished!
# MSR processing finished!
# MAR processing finished!
# MMR processing finished!
# NAM processing finished!
# NRU processing finished!
# NPL processing finished!
# NLD processing finished!
# NCL processing finished!
# NZL processing finished!
# NIC processing finished!
# NER processing finished!
# NIU processing finished!
# NFK processing finished!
# MNP processing finished!
# NOR processing finished!
# OMN processing finished!
# PAK processing finished!
# PLW processing finished!
# PSE processing finished!
# PAN processing finished!
# PNG processing finished!
# PRY processing finished!
# PER processing finished!
# PHL processing finished!
# PCN processing finished!
# POL processing finished!
# PRT processing finished!
# PRI processing finished!
# QAT processing finished!
# MKD processing finished!
# ROU processing finished!
# RUS processing finished!
# RWA processing finished!
# REU processing finished!
# BLM processing finished!
# SHN processing finished!
# KNA processing finished!
# LCA processing finished!
# MAF processing finished!
# SPM processing finished!
# VCT processing finished!
# WSM processing finished!
# SMR processing finished!
# STP processing finished!
# SAU processing finished!
# SEN processing finished!
# SRB processing finished!
# SYC processing finished!
# SLE processing finished!
# SGP processing finished!
# SXM processing finished!
# SVK processing finished!
# SVN processing finished!
# SLB processing finished!
# SOM processing finished!
# ZAF processing finished!
# SGS processing finished!
# SSD processing finished!
# ESP processing finished!
# LKA processing finished!
# SDN processing finished!
# SUR processing finished!
# SJM processing finished!
# SWE processing finished!
# CHE processing finished!
# SYR processing finished!
# TWN processing finished!
# TJK processing finished!
# TZA processing finished!
# THA processing finished!
# TLS processing finished!
# TGO processing finished!
# TKL processing finished!
# TON processing finished!
# TTO processing finished!
# TUN processing finished!
# TUR processing finished!
# TKM processing finished!
# TCA processing finished!
# TUV processing finished!
# UGA processing finished!
# UKR processing finished!
# ARE processing finished!
# GBR processing finished!
# UMI processing finished!
# USA processing finished!
# URY processing finished!
# VEN processing finished!
# VGB processing finished!
# WLF processing finished!
# ESH processing finished!
# YEM processing finished!
# ALA processing finished!
